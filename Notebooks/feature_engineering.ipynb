# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'C:\Users\HP\PW skills\SELF placed\Machine Learning\projects\Mini Hackathon!\data\processed\processed_data.csv')

# %%
df.shape
# Out:
# (944, 24)

# %% [markdown]
# # New feature age group

# %%
# Get the description of the age column to understand its distribution
age_description = df['Age'].describe()
print("Age Distribution Description:")
display(age_description)

# Based on the distribution, let's define some age bins.
# We can adjust these based on the describe output.
# For example, using quartiles or other logical groupings.
Q1 = df['Age'].quantile(0.25)
Q2 = df['Age'].quantile(0.50)
Q3 = df['Age'].quantile(0.75)

# Let's define bins based on quartiles and add some boundaries
age_bins = [df['Age'].min(), Q1, Q2, Q3, df['Age'].max()]
age_labels = ['Group 1', 'Group 2', 'Group 3', 'Group 4'] # Generic labels, can be customized

# Create a new column 'Age_Group' by categorizing 'Age' using the defined bins
df['Age_Group'] = pd.cut(df['Age'], bins=age_bins, labels=age_labels, include_lowest=True)

# Display the first few rows with the new 'Age_Group' column and the count of each group
display(df.head())
print("\nDistribution of Age Groups:")
display(df['Age_Group'].value_counts())
# Out:
# Age Distribution Description:
# count    944.000000
# mean      31.650424
# std        6.335163
# min       18.000000
# 25%       27.000000
# 50%       31.000000
# 75%       36.000000
# max       49.000000
# Name: Age, dtype: float64
#    Age  Gender  Country  self_employed  family_history  treatment  \
# 0   46       0        1              1               1          0
# 1   29       0        1              0               1          1
# 2   31       0        1              1               0          0
# 3   46       0        1              0               0          1
# 4   41       0        1              0               0          1
#
#    work_interfere  no_employees  remote_work  tech_company  ...  leave  \
# 0               1             0            1             1  ...      1
# 1               1             3            0             1  ...      0
# 2               0             0            1             1  ...      0
# ...

# %%
df.head()
# Out:
#    Age  Gender  Country  self_employed  family_history  treatment  \
# 0   46       0        1              1               1          0
# 1   29       0        1              0               1          1
# 2   31       0        1              1               0          0
# 3   46       0        1              0               0          1
# 4   41       0        1              0               0          1
#
#    work_interfere  no_employees  remote_work  tech_company  ...  leave  \
# 0               1             0            1             1  ...      1
# 1               1             3            0             1  ...      0
# 2               0             0            1             1  ...      0
# 3               1             2            1             1  ...      0
# 4               0             5            0             0  ...      0
#
#    mental_health_consequence  phys_health_consequence  coworkers  supervisor  \
# ...

# %%
procesed_df_fe = df.copy()
procesed_df_fe.to_csv(r'C:\Users\HP\PW skills\SELF placed\Machine Learning\projects\Mini Hackathon!\data\processed\processed_data.csv',index=False)
print("Processed data saved to 'processed_data_f_e.csv'")
# Out:
# Processed data saved to 'processed_data_f_e.csv'

# %%
sns.catplot(x=df['Age_Group'], hue='treatment', kind='count', data=df, height=6, aspect=1.5)
plt.title(f'Relationship between Age_Group and Treatment')
plt.xlabel("Age_Group")
plt.ylabel('Count')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 944 entries, 0 to 943
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        944 non-null    int64
#  1   Gender                     944 non-null    int64
#  2   Country                    944 non-null    int64
#  3   self_employed              944 non-null    int64
#  4   family_history             944 non-null    int64
#  5   treatment                  944 non-null    int64
#  6   work_interfere             944 non-null    int64
#  7   no_employees               944 non-null    int64
#  8   remote_work                944 non-null    int64
#  9   tech_company               944 non-null    int64
#  10  benefits                   944 non-null    int64
#  11  care_options               944 non-null    int64
#  12  wellness_program           944 non-null    int64
# ...
